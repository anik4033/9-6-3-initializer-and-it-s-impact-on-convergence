# %%
import os
import cv2
import pickle
from tqdm import tqdm
import pandas as pd 
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
print(tf.__version__)
# Out:
# 1.15.0

# %%
os.environ['TF_FORCE_GPU_ALLOW_GROWTH'] = 'true'
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'

physical_devices = tf.config.experimental.list_physical_devices('GPU')
if len(physical_devices) > 0:
    tf.config.experimental.set_memory_growth(physical_devices[0], True)

# %%
pickle_in = open("./data/train_x.pickle","rb")
train_x = pickle.load(pickle_in)

pickle_in = open("./data/train_y.pickle","rb")
train_y = pickle.load(pickle_in)

pickle_in = open("./data/test_x.pickle","rb")
test_x = pickle.load(pickle_in)

pickle_in = open("./data/test_y.pickle","rb")
test_y = pickle.load(pickle_in)

print(train_x.shape)
print(train_y.shape)
print(test_x.shape)
print(test_y.shape)
# Out:
# (2850, 60, 60, 3)
# (2850, 3)
# (150, 60, 60, 3)
# (150, 3)

# %%
num_classes = 3
n_input = 10800
learning_rate = 0.001
training_iters = 10
batch_size = 512
display_step = 20

# %%
img_size=60
num_channels=3
x = tf.compat.v1.placeholder(tf.float32, shape=[None, img_size,img_size,num_channels]) 
y_ = tf.compat.v1.placeholder(tf.float32, [None, num_classes])
print('Shape of placeholder',x.shape, y_.shape)
# Out:
# Shape of placeholder (?, 60, 60, 3) (?, 3)

# %%
def conv2d(x, W, b, strides=1):
    x = tf.nn.conv2d(x, W, strides=[1, strides, strides, 1], padding='SAME')
    x = tf.nn.bias_add(x, b)
    return tf.nn.relu(x)

def maxpool2d(x, k=2):
    return tf.nn.max_pool2d(x, ksize=[1, k, k, 1], strides=[1, k, k, 1], padding='SAME')

# %%
weights = {
    'w1': tf.Variable(tf.random.normal([5, 5, 3, 32])/np.sqrt(9),name='w1'),
    'w2': tf.Variable(tf.random.normal([5, 5, 32, 64])/(np.sqrt(6)),name='w2'),
    'w3': tf.Variable(tf.random.normal([5, 5, 64, 128])/(np.sqrt(3)),name='w3'),
    'wd1': tf.Variable(tf.random.normal([8 * 8 * 128, 2048]),name='wd1'),  
    'wout': tf.Variable(tf.random.normal([2048, num_classes]),name='wout')
}

biases = {
    'b1': tf.Variable(tf.random.normal([32])/np.sqrt(9),name='b1'),
    'b2': tf.Variable(tf.random.normal([64])/np.sqrt(6),name='b2'),
    'b3': tf.Variable(tf.random.normal([128])/np.sqrt(3),name='b3'),
    'bd1': tf.Variable(tf.random.normal([2048]),name='bd1'),
    'bout': tf.Variable(tf.random.normal([num_classes]),name='bout')
}

# %%
def conv_net(x, weights, biases):
        
    # reshape input to 60x60x3 size
    x = tf.reshape(x, shape=[-1, 60, 60, 3])  
    
    print("----------------------------------------------------------------------------")
    print("size of x is")
    print(x.shape)
    
  
    conv1 = conv2d(x, weights['w1'], biases['b1'])
    conv1 = maxpool2d(conv1, k=2)
    print("----------------------------------------------------------------------------")
    print("size after 1st conv layer is ")
    print(conv1.shape)

    
    #input is 30*30*32 image
    # Convolution Layer
    conv2 = conv2d(conv1, weights['w2'], biases['b2'])
    conv2 = maxpool2d(conv2, k=2)
    print("----------------------------------------------------------------------------")
    print("size after 2nd conv and pooling layer is")
    print(conv2.shape)
    
    
    ### third conv layer
    # input is 15*15*64 image
    # Convolution Layer
    conv3 = conv2d(conv2, weights['w3'], biases['b3'])
  
    conv3 = maxpool2d(conv3, k=2)
    print("----------------------------------------------------------------------------")
    print("size after 3rd conv and pooling layer is")
    print(conv3.shape)
    
    
    
    #input is 8*8*128 
    # Fully connected layer
    # Reshape conv3 output to fit fully connected layer input   = 8*8*128 = 8192
    fc1 = tf.reshape(conv3, [-1, weights['wd1'].get_shape().as_list()[0]])
    print("----------------------------------------------------------------------------")
    print("shape after flattening the image")
    print(fc1)  #8192 is the output
    
    
    fc1 = tf.add(tf.matmul(fc1, weights['wd1']), biases['bd1'])
    fc1 = tf.nn.relu(fc1)
    print("----------------------------------------------------------------------------")
    print("shape after fully connected layer")
    print(fc1)
    
    
    # Output, class prediction
    # finally we multiply the fully connected layer with the weights and add a bias term. 
    out = tf.add(tf.matmul(fc1, weights['wout']), biases['bout'])
    print("----------------------------------------------------------------------------")
    print("Output layer")
    return out

# %%
model = conv_net(x, weights, biases)
print(model)
# Out:
# ----------------------------------------------------------------------------
# size of x is
# (?, 60, 60, 3)
# ----------------------------------------------------------------------------
# size after 1st conv layer is
# (?, 30, 30, 32)
# ----------------------------------------------------------------------------
# size after 2nd conv and pooling layer is
# (?, 15, 15, 64)
# ----------------------------------------------------------------------------
# size after 3rd conv and pooling layer is
# (?, 8, 8, 128)
# ----------------------------------------------------------------------------
# shape after flattening the image
# Tensor("Reshape_1:0", shape=(?, 8192), dtype=float32)
# ----------------------------------------------------------------------------
# shape after fully connected layer
# Tensor("Relu_3:0", shape=(?, 2048), dtype=float32)
# ----------------------------------------------------------------------------
# Output layer
# Tensor("Add_1:0", shape=(?, 3), dtype=float32)

# %%
cost = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits_v2(logits=model, labels=y_))
optimizer = tf.compat.v1.train.AdamOptimizer(learning_rate=learning_rate).minimize(cost)

# %%
init = tf.compat.v1.global_variables_initializer()

# %%
cost_history=[]
n_epochs =500

sess = tf.compat.v1.Session()
sess.run(init)
train_y=train_y.todense()
for i in range(n_epochs):
    a, c = sess.run([optimizer, cost], feed_dict={x: train_x, y_: train_y})  
    cost_history = np.append(cost_history,c)  
    print('epoch : ', i, ' - ', 'cost: ', c)
# Out:
# epoch :  0  -  cost:  438331.78
# epoch :  1  -  cost:  496572.0
# epoch :  2  -  cost:  672233.25
# epoch :  3  -  cost:  552280.5
# epoch :  4  -  cost:  275761.38
# epoch :  5  -  cost:  220941.77
# epoch :  6  -  cost:  212010.94
# epoch :  7  -  cost:  316684.4
# epoch :  8  -  cost:  296594.8
# epoch :  9  -  cost:  187074.14
# epoch :  10  -  cost:  89648.54
# epoch :  11  -  cost:  105277.484
# epoch :  12  -  cost:  163373.8
# epoch :  13  -  cost:  184547.77
# epoch :  14  -  cost:  164844.61
# epoch :  15  -  cost:  126085.77
# epoch :  16  -  cost:  85077.22
# epoch :  17  -  cost:  67499.555
# epoch :  18  -  cost:  87526.98
# epoch :  19  -  cost:  108837.01
# epoch :  20  -  cost:  101306.14
# epoch :  21  -  cost:  71303.11
# epoch :  22  -  cost:  53516.957
# epoch :  23  -  cost:  64557.543
# epoch :  24  -  cost:  71697.71
# epoch :  25  -  cost:  67890.6
# epoch :  26  -  cost:  62033.785
# epoch :  27  -  cost:  54470.707
# epoch :  28  -  cost:  48740.65
# epoch :  29  -  cost:  49781.973
# epoch :  30  -  cost:  51257.17
# epoch :  31  -  cost:  48003.016
# epoch :  32  -  cost:  45686.09
# epoch :  33  -  cost:  46615.383
# epoch :  34  -  cost:  43237.332
# epoch :  35  -  cost:  36652.586
# epoch :  36  -  cost:  35709.973
# epoch :  37  -  cost:  39645.91
# epoch :  38  -  cost:  40034.43
# epoch :  39  -  cost:  35448.812
# epoch :  40  -  cost:  30984.129
# epoch :  41  -  cost:  30490.012
# epoch :  42  -  cost:  33545.9
# epoch :  43  -  cost:  33906.223
# epoch :  44  -  cost:  30426.678
# epoch :  45  -  cost:  27608.83
# epoch :  46  -  cost:  27550.86
# epoch :  47  -  cost:  28010.57
# epoch :  48  -  cost:  27802.08
# epoch :  49  -  cost:  26581.984
# epoch :  50  -  cost:  25207.498
# epoch :  51  -  cost:  24340.371
# epoch :  52  -  cost:  23937.771
# epoch :  53  -  cost:  23889.67
# epoch :  54  -  cost:  23806.502
# epoch :  55  -  cost:  22714.65
# epoch :  56  -  cost:  21286.664
# epoch :  57  -  cost:  20932.469
# epoch :  58  -  cost:  21341.36
# epoch :  59  -  cost:  20817.094
# epoch :  60  -  cost:  19577.283
# epoch :  61  -  cost:  19056.441
# epoch :  62  -  cost:  18956.732
# epoch :  63  -  cost:  18550.928
# epoch :  64  -  cost:  18033.996
# epoch :  65  -  cost:  17490.623
# epoch :  66  -  cost:  16803.463
# epoch :  67  -  cost:  16460.83
# epoch :  68  -  cost:  16356.779
# epoch :  69  -  cost:  15745.447
# epoch :  70  -  cost:  15054.684
# epoch :  71  -  cost:  14831.522
# epoch :  72  -  cost:  14568.238
# epoch :  73  -  cost:  14008.773
# epoch :  74  -  cost:  13565.458
# epoch :  75  -  cost:  13247.238
# epoch :  76  -  cost:  12912.654
# epoch :  77  -  cost:  12502.739
# epoch :  78  -  cost:  12029.805
# epoch :  79  -  cost:  11821.598
# epoch :  80  -  cost:  11440.856
# epoch :  81  -  cost:  11025.747
# epoch :  82  -  cost:  10725.827
# epoch :  83  -  cost:  10407.738
# epoch :  84  -  cost:  10086.922
# epoch :  85  -  cost:  9716.481
# epoch :  86  -  cost:  9485.312
# epoch :  87  -  cost:  9118.717
# epoch :  88  -  cost:  8825.774
# epoch :  89  -  cost:  8526.525
# epoch :  90  -  cost:  8254.388
# epoch :  91  -  cost:  7947.8286
# epoch :  92  -  cost:  7701.2676
# epoch :  93  -  cost:  7435.2886
# epoch :  94  -  cost:  7177.035
# epoch :  95  -  cost:  6929.337
# epoch :  96  -  cost:  6683.3633
# epoch :  97  -  cost:  6447.3984
# epoch :  98  -  cost:  6212.074
# epoch :  99  -  cost:  6005.9805
# epoch :  100  -  cost:  5771.278
# epoch :  101  -  cost:  5566.9116
# epoch :  102  -  cost:  5349.6084
# epoch :  103  -  cost:  5136.7476
# epoch :  104  -  cost:  4960.969
# epoch :  105  -  cost:  4774.3145
# epoch :  106  -  cost:  4597.745
# epoch :  107  -  cost:  4435.93
# epoch :  108  -  cost:  4280.095
# epoch :  109  -  cost:  4127.09
# epoch :  110  -  cost:  3967.398
# epoch :  111  -  cost:  3823.0122
# epoch :  112  -  cost:  3700.5684
# epoch :  113  -  cost:  3592.337
# epoch :  114  -  cost:  3449.2385
# epoch :  115  -  cost:  3308.0513
# epoch :  116  -  cost:  3178.1372
# epoch :  117  -  cost:  3066.7031
# epoch :  118  -  cost:  2971.4312
# epoch :  119  -  cost:  2898.4385
# epoch :  120  -  cost:  2799.761
# epoch :  121  -  cost:  2673.0176
# epoch :  122  -  cost:  2554.0151
# epoch :  123  -  cost:  2479.5764
# epoch :  124  -  cost:  2385.3484
# epoch :  125  -  cost:  2284.7053
# epoch :  126  -  cost:  2193.1968
# epoch :  127  -  cost:  2119.7576
# epoch :  128  -  cost:  2055.0881
# epoch :  129  -  cost:  1970.1869
# epoch :  130  -  cost:  1876.8386
# epoch :  131  -  cost:  1798.5872
# epoch :  132  -  cost:  1736.9441
# epoch :  133  -  cost:  1713.4895
# epoch :  134  -  cost:  1754.1056
# epoch :  135  -  cost:  1728.9045
# epoch :  136  -  cost:  1605.2372
# epoch :  137  -  cost:  1418.3837
# epoch :  138  -  cost:  1412.3817
# epoch :  139  -  cost:  1352.2137
# epoch :  140  -  cost:  1260.1003
# epoch :  141  -  cost:  1231.7388
# epoch :  142  -  cost:  1152.9932
# epoch :  143  -  cost:  1140.607
# epoch :  144  -  cost:  1061.1934
# epoch :  145  -  cost:  1027.0176
# epoch :  146  -  cost:  985.9898
# epoch :  147  -  cost:  934.12384
# epoch :  148  -  cost:  899.4388
# epoch :  149  -  cost:  869.79913
# epoch :  150  -  cost:  830.6352
# epoch :  151  -  cost:  797.2618
# epoch :  152  -  cost:  761.20764
# epoch :  153  -  cost:  733.0817
# epoch :  154  -  cost:  714.1127
# epoch :  155  -  cost:  713.5485
# epoch :  156  -  cost:  719.5601
# epoch :  157  -  cost:  670.25397
# epoch :  158  -  cost:  609.4019
# epoch :  159  -  cost:  596.4901
# epoch :  160  -  cost:  573.6955
# epoch :  161  -  cost:  550.8156
# epoch :  162  -  cost:  522.73157
# epoch :  163  -  cost:  508.47763
# epoch :  164  -  cost:  481.84863
# epoch :  165  -  cost:  461.61707
# epoch :  166  -  cost:  440.23358
# epoch :  167  -  cost:  417.1495
# epoch :  168  -  cost:  400.5634
# epoch :  169  -  cost:  379.29776
# epoch :  170  -  cost:  362.1775
# epoch :  171  -  cost:  350.95065
# epoch :  172  -  cost:  337.73734
# epoch :  173  -  cost:  340.59888
# epoch :  174  -  cost:  477.92636
# epoch :  175  -  cost:  661.7353
# epoch :  176  -  cost:  626.1958
# epoch :  177  -  cost:  306.98483
# epoch :  178  -  cost:  541.24725
# epoch :  179  -  cost:  596.67834
# epoch :  180  -  cost:  317.9719
# epoch :  181  -  cost:  420.4335
# epoch :  182  -  cost:  267.93097
# epoch :  183  -  cost:  358.18176
# epoch :  184  -  cost:  249.2224
# epoch :  185  -  cost:  260.1295
# epoch :  186  -  cost:  290.18903
# epoch :  187  -  cost:  216.2046
# epoch :  188  -  cost:  261.94025
# epoch :  189  -  cost:  216.38759
# epoch :  190  -  cost:  219.91243
# epoch :  191  -  cost:  197.71619
# epoch :  192  -  cost:  174.22887
# epoch :  193  -  cost:  202.51735
# epoch :  194  -  cost:  169.7402
# epoch :  195  -  cost:  154.55487
# epoch :  196  -  cost:  154.52959
# epoch :  197  -  cost:  158.41304
# epoch :  198  -  cost:  153.22742
# epoch :  199  -  cost:  139.4142
# epoch :  200  -  cost:  135.08774
# epoch :  201  -  cost:  127.75761
# epoch :  202  -  cost:  121.67072
# epoch :  203  -  cost:  122.41927
# epoch :  204  -  cost:  118.47228
# epoch :  205  -  cost:  109.70628
# epoch :  206  -  cost:  105.91559
# epoch :  207  -  cost:  103.48734
# epoch :  208  -  cost:  98.80902
# epoch :  209  -  cost:  95.41425
# epoch :  210  -  cost:  92.319115
# epoch :  211  -  cost:  87.22334
# epoch :  212  -  cost:  83.203705
# epoch :  213  -  cost:  80.88273
# epoch :  214  -  cost:  75.1752
# epoch :  215  -  cost:  71.51931
# epoch :  216  -  cost:  66.5206
# epoch :  217  -  cost:  62.91954
# epoch :  218  -  cost:  60.22574
# epoch :  219  -  cost:  58.0985
# epoch :  220  -  cost:  56.23727
# epoch :  221  -  cost:  53.915253
# epoch :  222  -  cost:  51.97597
# epoch :  223  -  cost:  48.850563
# epoch :  224  -  cost:  47.80722
# epoch :  225  -  cost:  44.873016
# epoch :  226  -  cost:  42.919884
# epoch :  227  -  cost:  41.873768
# epoch :  228  -  cost:  39.090084
# epoch :  229  -  cost:  37.358982
# epoch :  230  -  cost:  35.555027
# epoch :  231  -  cost:  33.30213
# epoch :  232  -  cost:  31.242413
# epoch :  233  -  cost:  30.249437
# epoch :  234  -  cost:  28.1505
# epoch :  235  -  cost:  25.576263
# epoch :  236  -  cost:  24.605154
# epoch :  237  -  cost:  23.48121
# epoch :  238  -  cost:  21.01745
# epoch :  239  -  cost:  21.406473
# epoch :  240  -  cost:  19.181108
# epoch :  241  -  cost:  18.713224
# epoch :  242  -  cost:  17.563278
# epoch :  243  -  cost:  15.840619
# epoch :  244  -  cost:  14.382239
# epoch :  245  -  cost:  13.249226
# epoch :  246  -  cost:  13.462047
# epoch :  247  -  cost:  12.632932
# epoch :  248  -  cost:  13.268965
# epoch :  249  -  cost:  11.066661
# epoch :  250  -  cost:  11.1532755
# epoch :  251  -  cost:  9.650728
# epoch :  252  -  cost:  10.187631
# epoch :  253  -  cost:  8.674221
# epoch :  254  -  cost:  8.829656
# epoch :  255  -  cost:  7.6811185
# epoch :  256  -  cost:  6.8170853
# epoch :  257  -  cost:  6.3821325
# epoch :  258  -  cost:  5.8432207
# epoch :  259  -  cost:  5.2076206
# epoch :  260  -  cost:  5.1036997
# epoch :  261  -  cost:  4.055277
# epoch :  262  -  cost:  3.5147724
# epoch :  263  -  cost:  3.0069928
# epoch :  264  -  cost:  2.5131176
# epoch :  265  -  cost:  2.9361384
# epoch :  266  -  cost:  1.5067211
# epoch :  267  -  cost:  3.7770994
# epoch :  268  -  cost:  1.8242363
# epoch :  269  -  cost:  3.1289792
# epoch :  270  -  cost:  0.083196275
# epoch :  271  -  cost:  4.949172
# epoch :  272  -  cost:  0.28451893
# epoch :  273  -  cost:  0.0
# epoch :  274  -  cost:  1.2869154
# epoch :  275  -  cost:  0.0640392
# epoch :  276  -  cost:  0.0
# epoch :  277  -  cost:  0.0
# epoch :  278  -  cost:  0.0
# epoch :  279  -  cost:  0.85180134
# epoch :  280  -  cost:  0.0
# epoch :  281  -  cost:  0.016699562
# epoch :  282  -  cost:  0.0
# epoch :  283  -  cost:  0.0
# epoch :  284  -  cost:  0.05272752
# epoch :  285  -  cost:  0.010844299
# epoch :  286  -  cost:  0.0
# epoch :  287  -  cost:  0.0
# epoch :  288  -  cost:  0.0
# epoch :  289  -  cost:  0.0
# epoch :  290  -  cost:  0.0
# epoch :  291  -  cost:  0.0
# epoch :  292  -  cost:  0.0
# epoch :  293  -  cost:  0.0
# epoch :  294  -  cost:  0.0
# epoch :  295  -  cost:  3.318313e-06
# epoch :  296  -  cost:  0.0046751653
# epoch :  297  -  cost:  0.0
# epoch :  298  -  cost:  0.0
# epoch :  299  -  cost:  0.0
# epoch :  300  -  cost:  0.07795539
# epoch :  301  -  cost:  0.0
# epoch :  302  -  cost:  0.0
# epoch :  303  -  cost:  0.021670436
# epoch :  304  -  cost:  0.0
# epoch :  305  -  cost:  0.0
# epoch :  306  -  cost:  0.0
# epoch :  307  -  cost:  0.0
# epoch :  308  -  cost:  0.0
# epoch :  309  -  cost:  5.85589e-10
# epoch :  310  -  cost:  0.010148369
# epoch :  311  -  cost:  0.0
# epoch :  312  -  cost:  0.0
# epoch :  313  -  cost:  0.0
# epoch :  314  -  cost:  0.0
# epoch :  315  -  cost:  0.0
# epoch :  316  -  cost:  0.0
# epoch :  317  -  cost:  4.0991024e-09
# epoch :  318  -  cost:  0.023119517
# epoch :  319  -  cost:  0.0
# epoch :  320  -  cost:  0.0
# epoch :  321  -  cost:  0.0
# epoch :  322  -  cost:  0.0
# epoch :  323  -  cost:  0.0
# epoch :  324  -  cost:  0.0
# epoch :  325  -  cost:  0.0
# epoch :  326  -  cost:  0.0
# epoch :  327  -  cost:  0.0
# epoch :  328  -  cost:  0.0
# epoch :  329  -  cost:  0.0
# epoch :  330  -  cost:  0.0
# epoch :  331  -  cost:  0.0
# epoch :  332  -  cost:  0.0
# epoch :  333  -  cost:  0.0
# epoch :  334  -  cost:  0.0
# epoch :  335  -  cost:  0.0
# epoch :  336  -  cost:  0.0
# epoch :  337  -  cost:  0.0
# epoch :  338  -  cost:  0.0
# epoch :  339  -  cost:  0.0
# epoch :  340  -  cost:  0.0
# epoch :  341  -  cost:  0.0
# epoch :  342  -  cost:  0.0
# epoch :  343  -  cost:  0.0
# epoch :  344  -  cost:  0.0
# epoch :  345  -  cost:  0.0
# epoch :  346  -  cost:  0.0
# epoch :  347  -  cost:  0.0
# epoch :  348  -  cost:  0.0
# epoch :  349  -  cost:  0.0
# epoch :  350  -  cost:  0.0
# epoch :  351  -  cost:  0.0
# epoch :  352  -  cost:  0.0
# epoch :  353  -  cost:  0.0
# epoch :  354  -  cost:  0.0
# epoch :  355  -  cost:  0.0
# epoch :  356  -  cost:  0.0
# epoch :  357  -  cost:  0.0
# epoch :  358  -  cost:  0.0
# epoch :  359  -  cost:  0.0
# epoch :  360  -  cost:  0.0
# epoch :  361  -  cost:  0.0
# epoch :  362  -  cost:  0.0
# epoch :  363  -  cost:  0.0
# epoch :  364  -  cost:  0.0
# epoch :  365  -  cost:  0.0
# epoch :  366  -  cost:  0.0
# epoch :  367  -  cost:  0.0
# epoch :  368  -  cost:  0.0
# epoch :  369  -  cost:  0.0
# epoch :  370  -  cost:  0.0
# epoch :  371  -  cost:  0.0
# epoch :  372  -  cost:  0.0
# epoch :  373  -  cost:  0.0
# epoch :  374  -  cost:  0.0
# epoch :  375  -  cost:  0.0
# epoch :  376  -  cost:  0.0
# epoch :  377  -  cost:  0.0
# epoch :  378  -  cost:  0.0
# epoch :  379  -  cost:  0.0
# epoch :  380  -  cost:  0.0
# epoch :  381  -  cost:  0.0
# epoch :  382  -  cost:  0.0
# epoch :  383  -  cost:  0.0
# epoch :  384  -  cost:  0.0
# epoch :  385  -  cost:  0.0
# epoch :  386  -  cost:  0.0
# epoch :  387  -  cost:  0.0
# epoch :  388  -  cost:  0.0
# epoch :  389  -  cost:  0.0
# epoch :  390  -  cost:  0.0
# epoch :  391  -  cost:  0.0
# epoch :  392  -  cost:  0.0
# epoch :  393  -  cost:  0.0
# epoch :  394  -  cost:  0.0
# epoch :  395  -  cost:  0.0
# epoch :  396  -  cost:  0.0
# epoch :  397  -  cost:  0.0
# epoch :  398  -  cost:  0.0
# epoch :  399  -  cost:  0.0
# epoch :  400  -  cost:  0.0
# epoch :  401  -  cost:  0.0
# epoch :  402  -  cost:  0.0
# epoch :  403  -  cost:  0.0
# epoch :  404  -  cost:  0.0
# epoch :  405  -  cost:  0.0
# epoch :  406  -  cost:  0.0
# epoch :  407  -  cost:  0.0
# epoch :  408  -  cost:  0.0
# epoch :  409  -  cost:  0.0
# epoch :  410  -  cost:  0.0
# epoch :  411  -  cost:  0.0
# epoch :  412  -  cost:  0.0
# epoch :  413  -  cost:  0.0
# epoch :  414  -  cost:  0.0
# epoch :  415  -  cost:  0.0
# epoch :  416  -  cost:  0.0
# epoch :  417  -  cost:  0.0
# epoch :  418  -  cost:  0.0
# epoch :  419  -  cost:  0.0
# epoch :  420  -  cost:  0.0
# epoch :  421  -  cost:  0.0
# epoch :  422  -  cost:  0.0
# epoch :  423  -  cost:  0.0
# epoch :  424  -  cost:  0.0
# epoch :  425  -  cost:  0.0
# epoch :  426  -  cost:  0.0
# epoch :  427  -  cost:  0.0
# epoch :  428  -  cost:  0.0
# epoch :  429  -  cost:  0.0
# epoch :  430  -  cost:  0.0
# epoch :  431  -  cost:  0.0
# epoch :  432  -  cost:  0.0
# epoch :  433  -  cost:  0.0
# epoch :  434  -  cost:  0.0
# epoch :  435  -  cost:  0.0
# epoch :  436  -  cost:  0.0
# epoch :  437  -  cost:  0.0
# epoch :  438  -  cost:  0.0
# epoch :  439  -  cost:  0.0
# epoch :  440  -  cost:  0.0
# epoch :  441  -  cost:  0.0
# epoch :  442  -  cost:  0.0
# epoch :  443  -  cost:  0.0
# epoch :  444  -  cost:  0.0
# epoch :  445  -  cost:  0.0
# epoch :  446  -  cost:  0.0
# epoch :  447  -  cost:  0.0
# epoch :  448  -  cost:  0.0
# epoch :  449  -  cost:  0.0
# epoch :  450  -  cost:  0.0
# epoch :  451  -  cost:  0.0
# epoch :  452  -  cost:  0.0
# epoch :  453  -  cost:  0.0
# epoch :  454  -  cost:  0.0
# epoch :  455  -  cost:  0.0
# epoch :  456  -  cost:  0.0
# epoch :  457  -  cost:  0.0
# epoch :  458  -  cost:  0.0
# epoch :  459  -  cost:  0.0
# epoch :  460  -  cost:  0.0
# epoch :  461  -  cost:  0.0
# epoch :  462  -  cost:  0.0
# epoch :  463  -  cost:  0.0
# epoch :  464  -  cost:  0.0
# epoch :  465  -  cost:  0.0
# epoch :  466  -  cost:  0.0
# epoch :  467  -  cost:  0.0
# epoch :  468  -  cost:  0.0
# epoch :  469  -  cost:  0.0
# epoch :  470  -  cost:  0.0
# epoch :  471  -  cost:  0.0
# epoch :  472  -  cost:  0.0
# epoch :  473  -  cost:  0.0
# epoch :  474  -  cost:  0.0
# epoch :  475  -  cost:  0.0
# epoch :  476  -  cost:  0.0
# epoch :  477  -  cost:  0.0
# epoch :  478  -  cost:  0.0
# epoch :  479  -  cost:  0.0
# epoch :  480  -  cost:  0.0
# epoch :  481  -  cost:  0.0
# epoch :  482  -  cost:  0.0
# epoch :  483  -  cost:  0.0
# epoch :  484  -  cost:  0.0
# epoch :  485  -  cost:  0.0
# epoch :  486  -  cost:  0.0
# epoch :  487  -  cost:  0.0
# epoch :  488  -  cost:  0.0
# epoch :  489  -  cost:  0.0
# epoch :  490  -  cost:  0.0
# epoch :  491  -  cost:  0.0
# epoch :  492  -  cost:  0.0
# epoch :  493  -  cost:  0.0
# epoch :  494  -  cost:  0.0
# epoch :  495  -  cost:  0.0
# epoch :  496  -  cost:  0.0
# epoch :  497  -  cost:  0.0
# epoch :  498  -  cost:  0.0
# epoch :  499  -  cost:  0.0

# %%
import matplotlib.pyplot as plt
plt.figure()
plt.plot(range(0,500), cost_history[0:500])
plt.ylabel('COST')
plt.xlabel('EPOCH')
plt.ylim([0, 1000])
plt.show()

# %%
test_y=test_y.todense() 
correct_prediction = tf.equal(tf.argmax(model,1), tf.argmax(y_,1))   
accuracy = tf.reduce_mean(tf.cast(correct_prediction, tf.float32))
print("Accuracy: ", sess.run(accuracy, feed_dict={x: test_x, y_:test_y}))
# Out:
# Accuracy:  0.62666667
