# %%
import os
import cv2
import pickle
from tqdm import tqdm
import pandas as pd 
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
print(tf.__version__)
# Out:
# 1.15.0

# %%
os.environ['TF_FORCE_GPU_ALLOW_GROWTH'] = 'true'
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'

physical_devices = tf.config.experimental.list_physical_devices('GPU')
if len(physical_devices) > 0:
    tf.config.experimental.set_memory_growth(physical_devices[0], True)

# %%
pickle_in = open("./data/train_x.pickle","rb")
train_x = pickle.load(pickle_in)

pickle_in = open("./data/train_y.pickle","rb")
train_y = pickle.load(pickle_in)

pickle_in = open("./data/test_x.pickle","rb")
test_x = pickle.load(pickle_in)

pickle_in = open("./data/test_y.pickle","rb")
test_y = pickle.load(pickle_in)

print(train_x.shape)
print(train_y.shape)
print(test_x.shape)
print(test_y.shape)
# Out:
# (2850, 60, 60, 3)
# (2850, 3)
# (150, 60, 60, 3)
# (150, 3)

# %%
num_classes = 3
n_input = 10800
learning_rate = 0.001
training_iters = 10
batch_size = 512
display_step = 20

# %%
img_size=60
num_channels=3
x = tf.compat.v1.placeholder(tf.float32, shape=[None, img_size,img_size,num_channels]) 
y_ = tf.compat.v1.placeholder(tf.float32, [None, num_classes])
print('Shape of placeholder',x.shape, y_.shape)
# Out:
# Shape of placeholder (?, 60, 60, 3) (?, 3)

# %%
def conv2d(x, W, b, strides=1):
    x = tf.nn.conv2d(x, W, strides=[1, strides, strides, 1], padding='SAME')
    x = tf.nn.bias_add(x, b)
    return tf.nn.relu(x)

def maxpool2d(x, k=2):
    return tf.nn.max_pool2d(x, ksize=[1, k, k, 1], strides=[1, k, k, 1], padding='SAME')

# %%
weights = {
    'w1': tf.Variable(tf.random.normal([5, 5, 3, 32])/np.sqrt(9),name='w1'),
    'w2': tf.Variable(tf.random.normal([5, 5, 32, 64])/(np.sqrt(6)),name='w2'),
    'w3': tf.Variable(tf.random.normal([5, 5, 64, 128])/(np.sqrt(3)),name='w3'),
    'wd1': tf.Variable(tf.random.normal([8 * 8 * 128, 2048]),name='wd1'),  
    'wout': tf.Variable(tf.random.normal([2048, num_classes]),name='wout')
}

biases = {
    'b1': tf.Variable(tf.random.normal([32])/np.sqrt(9),name='b1'),
    'b2': tf.Variable(tf.random.normal([64])/np.sqrt(6),name='b2'),
    'b3': tf.Variable(tf.random.normal([128])/np.sqrt(3),name='b3'),
    'bd1': tf.Variable(tf.random.normal([2048]),name='bd1'),
    'bout': tf.Variable(tf.random.normal([num_classes]),name='bout')
}

# %%
def conv_net(x, weights, biases):
        
    # reshape input to 60x60x3 size
    x = tf.reshape(x, shape=[-1, 60, 60, 3])  
    
    print("----------------------------------------------------------------------------")
    print("size of x is")
    print(x.shape)
    
  
    conv1 = conv2d(x, weights['w1'], biases['b1'])
    conv1 = maxpool2d(conv1, k=2)
    print("----------------------------------------------------------------------------")
    print("size after 1st conv layer is ")
    print(conv1.shape)

    
    #input is 30*30*32 image
    # Convolution Layer
    conv2 = conv2d(conv1, weights['w2'], biases['b2'])
    conv2 = maxpool2d(conv2, k=2)
    print("----------------------------------------------------------------------------")
    print("size after 2nd conv and pooling layer is")
    print(conv2.shape)
    
    
    ### third conv layer
    # input is 15*15*64 image
    # Convolution Layer
    conv3 = conv2d(conv2, weights['w3'], biases['b3'])
  
    conv3 = maxpool2d(conv3, k=2)
    print("----------------------------------------------------------------------------")
    print("size after 3rd conv and pooling layer is")
    print(conv3.shape)
    
    
    
    #input is 8*8*128 
    # Fully connected layer
    # Reshape conv3 output to fit fully connected layer input   = 8*8*128 = 8192
    fc1 = tf.reshape(conv3, [-1, weights['wd1'].get_shape().as_list()[0]])
    print("----------------------------------------------------------------------------")
    print("shape after flattening the image")
    print(fc1)  #8192 is the output
    
    
    fc1 = tf.add(tf.matmul(fc1, weights['wd1']), biases['bd1'])
    fc1 = tf.nn.relu(fc1)
    print("----------------------------------------------------------------------------")
    print("shape after fully connected layer")
    print(fc1)
    
    
    # Output, class prediction
    # finally we multiply the fully connected layer with the weights and add a bias term. 
    out = tf.add(tf.matmul(fc1, weights['wout']), biases['bout'])
    print("----------------------------------------------------------------------------")
    print("Output layer")
    return out

# %%
model = conv_net(x, weights, biases)
print(model)
# Out:
# ----------------------------------------------------------------------------
# size of x is
# (?, 60, 60, 3)
# ----------------------------------------------------------------------------
# size after 1st conv layer is
# (?, 30, 30, 32)
# ----------------------------------------------------------------------------
# size after 2nd conv and pooling layer is
# (?, 15, 15, 64)
# ----------------------------------------------------------------------------
# size after 3rd conv and pooling layer is
# (?, 8, 8, 128)
# ----------------------------------------------------------------------------
# shape after flattening the image
# Tensor("Reshape_1:0", shape=(?, 8192), dtype=float32)
# ----------------------------------------------------------------------------
# shape after fully connected layer
# Tensor("Relu_3:0", shape=(?, 2048), dtype=float32)
# ----------------------------------------------------------------------------
# Output layer
# Tensor("Add_1:0", shape=(?, 3), dtype=float32)

# %%
cost = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits_v2(logits=model, labels=y_))
optimizer = tf.compat.v1.train.AdamOptimizer(learning_rate=learning_rate).minimize(cost)

# %%
init = tf.compat.v1.global_variables_initializer()

# %%
cost_history=[]
n_epochs =500

sess = tf.compat.v1.Session()
sess.run(init)
train_y=train_y.todense()
for i in range(n_epochs):
    a, c = sess.run([optimizer, cost], feed_dict={x: train_x, y_: train_y})  
    cost_history = np.append(cost_history,c)  
    print('epoch : ', i, ' - ', 'cost: ', c)
# Out:
# epoch :  0  -  cost:  310650.28
# epoch :  1  -  cost:  338933.72
# epoch :  2  -  cost:  444854.97
# epoch :  3  -  cost:  365032.34
# epoch :  4  -  cost:  206820.84
# epoch :  5  -  cost:  151167.3
# epoch :  6  -  cost:  110866.46
# epoch :  7  -  cost:  197308.06
# epoch :  8  -  cost:  189560.56
# epoch :  9  -  cost:  106209.73
# epoch :  10  -  cost:  52324.773
# epoch :  11  -  cost:  72417.36
# epoch :  12  -  cost:  100600.81
# epoch :  13  -  cost:  111075.6
# epoch :  14  -  cost:  103087.13
# epoch :  15  -  cost:  82275.95
# epoch :  16  -  cost:  57790.99
# epoch :  17  -  cost:  42788.793
# epoch :  18  -  cost:  45778.508
# epoch :  19  -  cost:  59365.37
# epoch :  20  -  cost:  66674.03
# epoch :  21  -  cost:  60650.79
# epoch :  22  -  cost:  48052.17
# epoch :  23  -  cost:  38386.23
# epoch :  24  -  cost:  36060.082
# epoch :  25  -  cost:  39696.402
# epoch :  26  -  cost:  44493.242
# epoch :  27  -  cost:  45462.742
# epoch :  28  -  cost:  43017.07
# epoch :  29  -  cost:  38568.69
# epoch :  30  -  cost:  32991.176
# epoch :  31  -  cost:  29796.98
# epoch :  32  -  cost:  30114.352
# epoch :  33  -  cost:  31844.771
# epoch :  34  -  cost:  32859.215
# epoch :  35  -  cost:  31916.547
# epoch :  36  -  cost:  29001.041
# epoch :  37  -  cost:  25855.35
# epoch :  38  -  cost:  24870.08
# epoch :  39  -  cost:  25429.445
# epoch :  40  -  cost:  25849.45
# epoch :  41  -  cost:  25845.041
# epoch :  42  -  cost:  24863.27
# epoch :  43  -  cost:  22949.799
# epoch :  44  -  cost:  21491.957
# epoch :  45  -  cost:  20842.426
# epoch :  46  -  cost:  20819.453
# epoch :  47  -  cost:  21081.75
# epoch :  48  -  cost:  20696.469
# epoch :  49  -  cost:  19502.75
# epoch :  50  -  cost:  18422.734
# epoch :  51  -  cost:  17829.61
# epoch :  52  -  cost:  17705.365
# epoch :  53  -  cost:  17718.656
# epoch :  54  -  cost:  17191.623
# epoch :  55  -  cost:  16410.75
# epoch :  56  -  cost:  15630.861
# epoch :  57  -  cost:  15266.6
# epoch :  58  -  cost:  15187.868
# epoch :  59  -  cost:  14867.473
# epoch :  60  -  cost:  14404.767
# epoch :  61  -  cost:  13690.48
# epoch :  62  -  cost:  13355.512
# epoch :  63  -  cost:  13089.85
# epoch :  64  -  cost:  12882.184
# epoch :  65  -  cost:  12325.068
# epoch :  66  -  cost:  11937.236
# epoch :  67  -  cost:  11554.208
# epoch :  68  -  cost:  11400.229
# epoch :  69  -  cost:  10982.757
# epoch :  70  -  cost:  10608.832
# epoch :  71  -  cost:  10218.723
# epoch :  72  -  cost:  9962.012
# epoch :  73  -  cost:  9710.437
# epoch :  74  -  cost:  9323.472
# epoch :  75  -  cost:  8984.749
# epoch :  76  -  cost:  8727.67
# epoch :  77  -  cost:  8452.405
# epoch :  78  -  cost:  8160.397
# epoch :  79  -  cost:  7856.812
# epoch :  80  -  cost:  7571.584
# epoch :  81  -  cost:  7354.772
# epoch :  82  -  cost:  7116.3574
# epoch :  83  -  cost:  6843.254
# epoch :  84  -  cost:  6600.045
# epoch :  85  -  cost:  6356.685
# epoch :  86  -  cost:  6155.5444
# epoch :  87  -  cost:  5947.281
# epoch :  88  -  cost:  5710.746
# epoch :  89  -  cost:  5499.685
# epoch :  90  -  cost:  5334.3296
# epoch :  91  -  cost:  5131.703
# epoch :  92  -  cost:  4918.198
# epoch :  93  -  cost:  4740.369
# epoch :  94  -  cost:  4552.5444
# epoch :  95  -  cost:  4406.275
# epoch :  96  -  cost:  4277.7515
# epoch :  97  -  cost:  4242.811
# epoch :  98  -  cost:  4103.7676
# epoch :  99  -  cost:  3910.7703
# epoch :  100  -  cost:  3664.024
# epoch :  101  -  cost:  3535.325
# epoch :  102  -  cost:  3458.7593
# epoch :  103  -  cost:  3289.1782
# epoch :  104  -  cost:  3158.6182
# epoch :  105  -  cost:  3074.5994
# epoch :  106  -  cost:  2917.6106
# epoch :  107  -  cost:  2800.9807
# epoch :  108  -  cost:  2747.913
# epoch :  109  -  cost:  2586.0083
# epoch :  110  -  cost:  2467.2544
# epoch :  111  -  cost:  2383.0352
# epoch :  112  -  cost:  2265.2197
# epoch :  113  -  cost:  2173.9827
# epoch :  114  -  cost:  2102.085
# epoch :  115  -  cost:  2025.7291
# epoch :  116  -  cost:  2055.7004
# epoch :  117  -  cost:  2062.2644
# epoch :  118  -  cost:  2206.118
# epoch :  119  -  cost:  1812.1802
# epoch :  120  -  cost:  1617.7112
# epoch :  121  -  cost:  1624.0438
# epoch :  122  -  cost:  1515.1578
# epoch :  123  -  cost:  1430.9729
# epoch :  124  -  cost:  1392.1317
# epoch :  125  -  cost:  1295.4238
# epoch :  126  -  cost:  1280.3932
# epoch :  127  -  cost:  1215.5447
# epoch :  128  -  cost:  1141.6329
# epoch :  129  -  cost:  1127.4141
# epoch :  130  -  cost:  1069.1167
# epoch :  131  -  cost:  994.63226
# epoch :  132  -  cost:  973.9602
# epoch :  133  -  cost:  906.96326
# epoch :  134  -  cost:  888.5963
# epoch :  135  -  cost:  847.0457
# epoch :  136  -  cost:  787.5881
# epoch :  137  -  cost:  783.77264
# epoch :  138  -  cost:  753.59595
# epoch :  139  -  cost:  686.2902
# epoch :  140  -  cost:  670.3445
# epoch :  141  -  cost:  641.65326
# epoch :  142  -  cost:  599.7722
# epoch :  143  -  cost:  578.6283
# epoch :  144  -  cost:  547.34344
# epoch :  145  -  cost:  524.0889
# epoch :  146  -  cost:  496.68576
# epoch :  147  -  cost:  479.9385
# epoch :  148  -  cost:  452.54825
# epoch :  149  -  cost:  435.0341
# epoch :  150  -  cost:  419.56448
# epoch :  151  -  cost:  404.45444
# epoch :  152  -  cost:  379.8165
# epoch :  153  -  cost:  355.3075
# epoch :  154  -  cost:  342.3837
# epoch :  155  -  cost:  340.28864
# epoch :  156  -  cost:  347.24667
# epoch :  157  -  cost:  336.76965
# epoch :  158  -  cost:  324.6689
# epoch :  159  -  cost:  287.69128
# epoch :  160  -  cost:  317.48938
# epoch :  161  -  cost:  417.11105
# epoch :  162  -  cost:  434.0222
# epoch :  163  -  cost:  359.41095
# epoch :  164  -  cost:  255.54463
# epoch :  165  -  cost:  266.42404
# epoch :  166  -  cost:  255.73584
# epoch :  167  -  cost:  231.78142
# epoch :  168  -  cost:  245.14648
# epoch :  169  -  cost:  227.92126
# epoch :  170  -  cost:  207.92618
# epoch :  171  -  cost:  209.6999
# epoch :  172  -  cost:  203.60008
# epoch :  173  -  cost:  183.6363
# epoch :  174  -  cost:  177.87672
# epoch :  175  -  cost:  185.71342
# epoch :  176  -  cost:  164.54295
# epoch :  177  -  cost:  187.45256
# epoch :  178  -  cost:  154.3758
# epoch :  179  -  cost:  153.77554
# epoch :  180  -  cost:  159.99277
# epoch :  181  -  cost:  139.87961
# epoch :  182  -  cost:  135.11987
# epoch :  183  -  cost:  142.29384
# epoch :  184  -  cost:  123.76296
# epoch :  185  -  cost:  118.93268
# epoch :  186  -  cost:  119.13684
# epoch :  187  -  cost:  113.24498
# epoch :  188  -  cost:  104.91224
# epoch :  189  -  cost:  101.02681
# epoch :  190  -  cost:  100.809845
# epoch :  191  -  cost:  95.38885
# epoch :  192  -  cost:  88.95198
# epoch :  193  -  cost:  85.5728
# epoch :  194  -  cost:  82.996635
# epoch :  195  -  cost:  78.58528
# epoch :  196  -  cost:  74.69057
# epoch :  197  -  cost:  71.243935
# epoch :  198  -  cost:  67.555244
# epoch :  199  -  cost:  64.7142
# epoch :  200  -  cost:  61.51426
# epoch :  201  -  cost:  57.99932
# epoch :  202  -  cost:  56.213593
# epoch :  203  -  cost:  55.159412
# epoch :  204  -  cost:  52.03148
# epoch :  205  -  cost:  49.293518
# epoch :  206  -  cost:  46.985413
# epoch :  207  -  cost:  45.321163
# epoch :  208  -  cost:  43.03459
# epoch :  209  -  cost:  41.003735
# epoch :  210  -  cost:  38.807713
# epoch :  211  -  cost:  36.710125
# epoch :  212  -  cost:  34.251347
# epoch :  213  -  cost:  32.514004
# epoch :  214  -  cost:  30.462585
# epoch :  215  -  cost:  28.373482
# epoch :  216  -  cost:  26.564646
# epoch :  217  -  cost:  25.250584
# epoch :  218  -  cost:  26.572405
# epoch :  219  -  cost:  31.229027
# epoch :  220  -  cost:  27.722713
# epoch :  221  -  cost:  21.950054
# epoch :  222  -  cost:  20.02488
# epoch :  223  -  cost:  19.634123
# epoch :  224  -  cost:  19.643496
# epoch :  225  -  cost:  17.516188
# epoch :  226  -  cost:  15.850274
# epoch :  227  -  cost:  14.508983
# epoch :  228  -  cost:  14.085699
# epoch :  229  -  cost:  12.5371685
# epoch :  230  -  cost:  11.331464
# epoch :  231  -  cost:  10.625219
# epoch :  232  -  cost:  10.087459
# epoch :  233  -  cost:  8.68739
# epoch :  234  -  cost:  7.5483937
# epoch :  235  -  cost:  6.1033826
# epoch :  236  -  cost:  4.8356557
# epoch :  237  -  cost:  4.0099974
# epoch :  238  -  cost:  3.2774012
# epoch :  239  -  cost:  2.8307018
# epoch :  240  -  cost:  2.6039145
# epoch :  241  -  cost:  1.8672643
# epoch :  242  -  cost:  1.4329002
# epoch :  243  -  cost:  0.7904002
# epoch :  244  -  cost:  0.2166886
# epoch :  245  -  cost:  0.12659752
# epoch :  246  -  cost:  0.10544957
# epoch :  247  -  cost:  0.045411184
# epoch :  248  -  cost:  0.07331689
# epoch :  249  -  cost:  0.15629934
# epoch :  250  -  cost:  3.099745e-07
# epoch :  251  -  cost:  0.04276316
# epoch :  252  -  cost:  0.031683113
# epoch :  253  -  cost:  0.0
# epoch :  254  -  cost:  0.08823088
# epoch :  255  -  cost:  0.02725603
# epoch :  256  -  cost:  0.0
# epoch :  257  -  cost:  0.0
# epoch :  258  -  cost:  0.0
# epoch :  259  -  cost:  0.0
# epoch :  260  -  cost:  0.0
# epoch :  261  -  cost:  0.020597588
# epoch :  262  -  cost:  0.0
# epoch :  263  -  cost:  0.0
# epoch :  264  -  cost:  0.01723136
# epoch :  265  -  cost:  0.0
# epoch :  266  -  cost:  0.0
# epoch :  267  -  cost:  0.0
# epoch :  268  -  cost:  0.0
# epoch :  269  -  cost:  0.0
# epoch :  270  -  cost:  0.0
# epoch :  271  -  cost:  0.0
# epoch :  272  -  cost:  0.0
# epoch :  273  -  cost:  0.0006516586
# epoch :  274  -  cost:  0.0
# epoch :  275  -  cost:  0.03854715
# epoch :  276  -  cost:  0.0
# epoch :  277  -  cost:  0.0
# epoch :  278  -  cost:  0.0
# epoch :  279  -  cost:  0.0
# epoch :  280  -  cost:  0.02495614
# epoch :  281  -  cost:  0.0
# epoch :  282  -  cost:  0.0
# epoch :  283  -  cost:  0.0
# epoch :  284  -  cost:  0.0
# epoch :  285  -  cost:  0.0
# epoch :  286  -  cost:  0.0
# epoch :  287  -  cost:  0.0
# epoch :  288  -  cost:  0.0
# epoch :  289  -  cost:  0.0
# epoch :  290  -  cost:  0.0
# epoch :  291  -  cost:  0.0
# epoch :  292  -  cost:  0.0
# epoch :  293  -  cost:  0.0
# epoch :  294  -  cost:  0.0
# epoch :  295  -  cost:  0.0
# epoch :  296  -  cost:  0.0
# epoch :  297  -  cost:  4.1827797e-10
# epoch :  298  -  cost:  4.571483e-08
# epoch :  299  -  cost:  2.5669303e-06
# epoch :  300  -  cost:  1.19882925e-05
# epoch :  301  -  cost:  0.0
# epoch :  302  -  cost:  0.0
# epoch :  303  -  cost:  0.0
# epoch :  304  -  cost:  0.0
# epoch :  305  -  cost:  0.0
# epoch :  306  -  cost:  0.0
# epoch :  307  -  cost:  0.0
# epoch :  308  -  cost:  0.0
# epoch :  309  -  cost:  0.0
# epoch :  310  -  cost:  0.0
# epoch :  311  -  cost:  0.0
# epoch :  312  -  cost:  0.0
# epoch :  313  -  cost:  0.0
# epoch :  314  -  cost:  0.0
# epoch :  315  -  cost:  0.0
# epoch :  316  -  cost:  0.0
# epoch :  317  -  cost:  0.0
# epoch :  318  -  cost:  0.0
# epoch :  319  -  cost:  0.0
# epoch :  320  -  cost:  0.0
# epoch :  321  -  cost:  0.0
# epoch :  322  -  cost:  0.0
# epoch :  323  -  cost:  0.0
# epoch :  324  -  cost:  0.0
# epoch :  325  -  cost:  0.0
# epoch :  326  -  cost:  0.0
# epoch :  327  -  cost:  0.0
# epoch :  328  -  cost:  0.0
# epoch :  329  -  cost:  0.0
# epoch :  330  -  cost:  0.0
# epoch :  331  -  cost:  0.0
# epoch :  332  -  cost:  0.0
# epoch :  333  -  cost:  0.0
# epoch :  334  -  cost:  0.0
# epoch :  335  -  cost:  0.0
# epoch :  336  -  cost:  0.0
# epoch :  337  -  cost:  0.0
# epoch :  338  -  cost:  0.0
# epoch :  339  -  cost:  0.0
# epoch :  340  -  cost:  0.0
# epoch :  341  -  cost:  0.0
# epoch :  342  -  cost:  0.0
# epoch :  343  -  cost:  0.0
# epoch :  344  -  cost:  0.0
# epoch :  345  -  cost:  0.0
# epoch :  346  -  cost:  0.0
# epoch :  347  -  cost:  0.0
# epoch :  348  -  cost:  0.0
# epoch :  349  -  cost:  0.0
# epoch :  350  -  cost:  0.0
# epoch :  351  -  cost:  0.0
# epoch :  352  -  cost:  0.0
# epoch :  353  -  cost:  0.0
# epoch :  354  -  cost:  0.0
# epoch :  355  -  cost:  0.0
# epoch :  356  -  cost:  0.0
# epoch :  357  -  cost:  0.0
# epoch :  358  -  cost:  0.0
# epoch :  359  -  cost:  0.0
# epoch :  360  -  cost:  0.0
# epoch :  361  -  cost:  0.0
# epoch :  362  -  cost:  0.0
# epoch :  363  -  cost:  0.0
# epoch :  364  -  cost:  0.0
# epoch :  365  -  cost:  0.0
# epoch :  366  -  cost:  0.0
# epoch :  367  -  cost:  0.0
# epoch :  368  -  cost:  0.0
# epoch :  369  -  cost:  0.0
# epoch :  370  -  cost:  0.0
# epoch :  371  -  cost:  0.0
# epoch :  372  -  cost:  0.0
# epoch :  373  -  cost:  0.0
# epoch :  374  -  cost:  0.0
# epoch :  375  -  cost:  0.0
# epoch :  376  -  cost:  0.0
# epoch :  377  -  cost:  0.0
# epoch :  378  -  cost:  0.0
# epoch :  379  -  cost:  0.0
# epoch :  380  -  cost:  0.0
# epoch :  381  -  cost:  0.0
# epoch :  382  -  cost:  0.0
# epoch :  383  -  cost:  0.0
# epoch :  384  -  cost:  0.0
# epoch :  385  -  cost:  0.0
# epoch :  386  -  cost:  0.0
# epoch :  387  -  cost:  0.0
# epoch :  388  -  cost:  0.0
# epoch :  389  -  cost:  0.0
# epoch :  390  -  cost:  0.0
# epoch :  391  -  cost:  0.0
# epoch :  392  -  cost:  0.0
# epoch :  393  -  cost:  0.0
# epoch :  394  -  cost:  0.0
# epoch :  395  -  cost:  0.0
# epoch :  396  -  cost:  0.0
# epoch :  397  -  cost:  0.0
# epoch :  398  -  cost:  0.0
# epoch :  399  -  cost:  0.0
# epoch :  400  -  cost:  0.0
# epoch :  401  -  cost:  0.0
# epoch :  402  -  cost:  0.0
# epoch :  403  -  cost:  0.0
# epoch :  404  -  cost:  0.0
# epoch :  405  -  cost:  0.0
# epoch :  406  -  cost:  0.0
# epoch :  407  -  cost:  0.0
# epoch :  408  -  cost:  0.0
# epoch :  409  -  cost:  0.0
# epoch :  410  -  cost:  0.0
# epoch :  411  -  cost:  0.0
# epoch :  412  -  cost:  0.0
# epoch :  413  -  cost:  0.0
# epoch :  414  -  cost:  0.0
# epoch :  415  -  cost:  0.0
# epoch :  416  -  cost:  0.0
# epoch :  417  -  cost:  0.0
# epoch :  418  -  cost:  0.0
# epoch :  419  -  cost:  0.0
# epoch :  420  -  cost:  0.0
# epoch :  421  -  cost:  0.0
# epoch :  422  -  cost:  0.0
# epoch :  423  -  cost:  0.0
# epoch :  424  -  cost:  0.0
# epoch :  425  -  cost:  0.0
# epoch :  426  -  cost:  0.0
# epoch :  427  -  cost:  0.0
# epoch :  428  -  cost:  0.0
# epoch :  429  -  cost:  0.0
# epoch :  430  -  cost:  0.0
# epoch :  431  -  cost:  0.0
# epoch :  432  -  cost:  0.0
# epoch :  433  -  cost:  0.0
# epoch :  434  -  cost:  0.0
# epoch :  435  -  cost:  0.0
# epoch :  436  -  cost:  0.0
# epoch :  437  -  cost:  0.0
# epoch :  438  -  cost:  0.0
# epoch :  439  -  cost:  0.0
# epoch :  440  -  cost:  0.0
# epoch :  441  -  cost:  0.0
# epoch :  442  -  cost:  0.0
# epoch :  443  -  cost:  0.0
# epoch :  444  -  cost:  0.0
# epoch :  445  -  cost:  0.0
# epoch :  446  -  cost:  0.0
# epoch :  447  -  cost:  0.0
# epoch :  448  -  cost:  0.0
# epoch :  449  -  cost:  0.0
# epoch :  450  -  cost:  0.0
# epoch :  451  -  cost:  0.0
# epoch :  452  -  cost:  0.0
# epoch :  453  -  cost:  0.0
# epoch :  454  -  cost:  0.0
# epoch :  455  -  cost:  0.0
# epoch :  456  -  cost:  0.0
# epoch :  457  -  cost:  0.0
# epoch :  458  -  cost:  0.0
# epoch :  459  -  cost:  0.0
# epoch :  460  -  cost:  0.0
# epoch :  461  -  cost:  0.0
# epoch :  462  -  cost:  0.0
# epoch :  463  -  cost:  0.0
# epoch :  464  -  cost:  0.0
# epoch :  465  -  cost:  0.0
# epoch :  466  -  cost:  0.0
# epoch :  467  -  cost:  0.0
# epoch :  468  -  cost:  0.0
# epoch :  469  -  cost:  0.0
# epoch :  470  -  cost:  0.0
# epoch :  471  -  cost:  0.0
# epoch :  472  -  cost:  0.0
# epoch :  473  -  cost:  0.0
# epoch :  474  -  cost:  0.0
# epoch :  475  -  cost:  0.0
# epoch :  476  -  cost:  0.0
# epoch :  477  -  cost:  0.0
# epoch :  478  -  cost:  0.0
# epoch :  479  -  cost:  0.0
# epoch :  480  -  cost:  0.0
# epoch :  481  -  cost:  0.0
# epoch :  482  -  cost:  0.0
# epoch :  483  -  cost:  0.0
# epoch :  484  -  cost:  0.0
# epoch :  485  -  cost:  0.0
# epoch :  486  -  cost:  0.0
# epoch :  487  -  cost:  0.0
# epoch :  488  -  cost:  0.0
# epoch :  489  -  cost:  0.0
# epoch :  490  -  cost:  0.0
# epoch :  491  -  cost:  0.0
# epoch :  492  -  cost:  0.0
# epoch :  493  -  cost:  0.0
# epoch :  494  -  cost:  0.0
# epoch :  495  -  cost:  0.0
# epoch :  496  -  cost:  0.0
# epoch :  497  -  cost:  0.0
# epoch :  498  -  cost:  0.0
# epoch :  499  -  cost:  0.0

# %%
import matplotlib.pyplot as plt
plt.figure()
plt.plot(range(0,500), cost_history[0:500])
plt.ylabel('COST')
plt.xlabel('EPOCH')
plt.ylim([0, 1000])
plt.show()

# %%
test_y=test_y.todense() 
correct_prediction = tf.equal(tf.argmax(model,1), tf.argmax(y_,1))   
accuracy = tf.reduce_mean(tf.cast(correct_prediction, tf.float32))
print("Accuracy: ", sess.run(accuracy, feed_dict={x: test_x, y_:test_y}))
# Out:
# Accuracy:  0.6533333
