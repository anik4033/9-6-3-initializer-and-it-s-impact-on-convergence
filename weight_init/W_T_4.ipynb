# %%
import os
import cv2
import pickle
from tqdm import tqdm
import pandas as pd 
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
print(tf.__version__)
# Out:
# 1.15.0

# %%
os.environ['TF_FORCE_GPU_ALLOW_GROWTH'] = 'true'
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'

physical_devices = tf.config.experimental.list_physical_devices('GPU')
if len(physical_devices) > 0:
    tf.config.experimental.set_memory_growth(physical_devices[0], True)

# %%
pickle_in = open("./data/train_x.pickle","rb")
train_x = pickle.load(pickle_in)

pickle_in = open("./data/train_y.pickle","rb")
train_y = pickle.load(pickle_in)

pickle_in = open("./data/test_x.pickle","rb")
test_x = pickle.load(pickle_in)

pickle_in = open("./data/test_y.pickle","rb")
test_y = pickle.load(pickle_in)

print(train_x.shape)
print(train_y.shape)
print(test_x.shape)
print(test_y.shape)
# Out:
# (2850, 60, 60, 3)
# (2850, 3)
# (150, 60, 60, 3)
# (150, 3)

# %%
num_classes = 3
n_input = 10800
learning_rate = 0.001
training_iters = 10
batch_size = 512
display_step = 20

# %%
img_size=60
num_channels=3
x = tf.compat.v1.placeholder(tf.float32, shape=[None, img_size,img_size,num_channels]) 
y_ = tf.compat.v1.placeholder(tf.float32, [None, num_classes])
print('Shape of placeholder',x.shape, y_.shape)
# Out:
# Shape of placeholder (?, 60, 60, 3) (?, 3)

# %%
def conv2d(x, W, b, strides=1):
    x = tf.nn.conv2d(x, W, strides=[1, strides, strides, 1], padding='SAME')
    x = tf.nn.bias_add(x, b)
    return tf.nn.relu(x)

def maxpool2d(x, k=2):
    return tf.nn.max_pool2d(x, ksize=[1, k, k, 1], strides=[1, k, k, 1], padding='SAME')

# %%
weights = {
    'w1': tf.Variable(tf.random.normal([5, 5, 3, 32])/np.sqrt(9),name='w1'),
    'w2': tf.Variable(tf.random.normal([5, 5, 32, 64])/(np.sqrt(6)),name='w2'),
    'w3': tf.Variable(tf.random.normal([5, 5, 64, 128])/(np.sqrt(3)),name='w3'),
    'wd1': tf.Variable(tf.random.normal([8 * 8 * 128, 2048]),name='wd1'),  
    'wout': tf.Variable(tf.random.normal([2048, num_classes]),name='wout')
}

biases = {
    'b1': tf.Variable(tf.random.normal([32])/np.sqrt(9),name='b1'),
    'b2': tf.Variable(tf.random.normal([64])/np.sqrt(6),name='b2'),
    'b3': tf.Variable(tf.random.normal([128])/np.sqrt(3),name='b3'),
    'bd1': tf.Variable(tf.random.normal([2048]),name='bd1'),
    'bout': tf.Variable(tf.random.normal([num_classes]),name='bout')
}

# %%
def conv_net(x, weights, biases):
        
    # reshape input to 60x60x3 size
    x = tf.reshape(x, shape=[-1, 60, 60, 3])  
    
    print("----------------------------------------------------------------------------")
    print("size of x is")
    print(x.shape)
    
  
    conv1 = conv2d(x, weights['w1'], biases['b1'])
    conv1 = maxpool2d(conv1, k=2)
    print("----------------------------------------------------------------------------")
    print("size after 1st conv layer is ")
    print(conv1.shape)

    
    #input is 30*30*32 image
    # Convolution Layer
    conv2 = conv2d(conv1, weights['w2'], biases['b2'])
    conv2 = maxpool2d(conv2, k=2)
    print("----------------------------------------------------------------------------")
    print("size after 2nd conv and pooling layer is")
    print(conv2.shape)
    
    
    ### third conv layer
    # input is 15*15*64 image
    # Convolution Layer
    conv3 = conv2d(conv2, weights['w3'], biases['b3'])
  
    conv3 = maxpool2d(conv3, k=2)
    print("----------------------------------------------------------------------------")
    print("size after 3rd conv and pooling layer is")
    print(conv3.shape)
    
    
    
    #input is 8*8*128 
    # Fully connected layer
    # Reshape conv3 output to fit fully connected layer input   = 8*8*128 = 8192
    fc1 = tf.reshape(conv3, [-1, weights['wd1'].get_shape().as_list()[0]])
    print("----------------------------------------------------------------------------")
    print("shape after flattening the image")
    print(fc1)  #8192 is the output
    
    
    fc1 = tf.add(tf.matmul(fc1, weights['wd1']), biases['bd1'])
    fc1 = tf.nn.relu(fc1)
    print("----------------------------------------------------------------------------")
    print("shape after fully connected layer")
    print(fc1)
    
    
    # Output, class prediction
    # finally we multiply the fully connected layer with the weights and add a bias term. 
    out = tf.add(tf.matmul(fc1, weights['wout']), biases['bout'])
    print("----------------------------------------------------------------------------")
    print("Output layer")
    return out

# %%
model = conv_net(x, weights, biases)
print(model)
# Out:
# ----------------------------------------------------------------------------
# size of x is
# (?, 60, 60, 3)
# ----------------------------------------------------------------------------
# size after 1st conv layer is
# (?, 30, 30, 32)
# ----------------------------------------------------------------------------
# size after 2nd conv and pooling layer is
# (?, 15, 15, 64)
# ----------------------------------------------------------------------------
# size after 3rd conv and pooling layer is
# (?, 8, 8, 128)
# ----------------------------------------------------------------------------
# shape after flattening the image
# Tensor("Reshape_1:0", shape=(?, 8192), dtype=float32)
# ----------------------------------------------------------------------------
# shape after fully connected layer
# Tensor("Relu_3:0", shape=(?, 2048), dtype=float32)
# ----------------------------------------------------------------------------
# Output layer
# Tensor("Add_1:0", shape=(?, 3), dtype=float32)

# %%
cost = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits_v2(logits=model, labels=y_))
optimizer = tf.compat.v1.train.AdamOptimizer(learning_rate=learning_rate).minimize(cost)

# %%
init = tf.compat.v1.global_variables_initializer()

# %%
cost_history=[]
n_epochs =500

sess = tf.compat.v1.Session()
sess.run(init)
train_y=train_y.todense()
for i in range(n_epochs):
    a, c = sess.run([optimizer, cost], feed_dict={x: train_x, y_: train_y})  
    cost_history = np.append(cost_history,c)  
    print('epoch : ', i, ' - ', 'cost: ', c)
# Out:
# epoch :  0  -  cost:  442995.5
# epoch :  1  -  cost:  275980.25
# epoch :  2  -  cost:  445302.0
# epoch :  3  -  cost:  371454.6
# epoch :  4  -  cost:  213724.83
# epoch :  5  -  cost:  177618.3
# epoch :  6  -  cost:  97450.06
# epoch :  7  -  cost:  194068.48
# epoch :  8  -  cost:  213204.53
# epoch :  9  -  cost:  135153.52
# epoch :  10  -  cost:  59354.926
# epoch :  11  -  cost:  82121.44
# epoch :  12  -  cost:  120810.63
# epoch :  13  -  cost:  135572.39
# epoch :  14  -  cost:  127758.99
# epoch :  15  -  cost:  101521.0
# epoch :  16  -  cost:  65311.45
# epoch :  17  -  cost:  47832.758
# epoch :  18  -  cost:  65215.023
# epoch :  19  -  cost:  80672.34
# epoch :  20  -  cost:  72251.78
# epoch :  21  -  cost:  55244.047
# epoch :  22  -  cost:  55635.445
# epoch :  23  -  cost:  56929.0
# epoch :  24  -  cost:  46273.953
# epoch :  25  -  cost:  40820.777
# epoch :  26  -  cost:  47831.574
# epoch :  27  -  cost:  52956.61
# epoch :  28  -  cost:  47098.758
# epoch :  29  -  cost:  36154.402
# epoch :  30  -  cost:  31805.53
# epoch :  31  -  cost:  36457.105
# epoch :  32  -  cost:  39900.766
# epoch :  33  -  cost:  36179.13
# epoch :  34  -  cost:  33016.496
# epoch :  35  -  cost:  32568.674
# epoch :  36  -  cost:  30647.584
# epoch :  37  -  cost:  27801.484
# epoch :  38  -  cost:  27885.24
# epoch :  39  -  cost:  30236.336
# epoch :  40  -  cost:  30054.682
# epoch :  41  -  cost:  26771.39
# epoch :  42  -  cost:  24247.762
# epoch :  43  -  cost:  24498.941
# epoch :  44  -  cost:  24817.56
# epoch :  45  -  cost:  23753.002
# epoch :  46  -  cost:  23400.2
# epoch :  47  -  cost:  23370.158
# epoch :  48  -  cost:  21635.678
# epoch :  49  -  cost:  20127.006
# epoch :  50  -  cost:  20475.152
# epoch :  51  -  cost:  20884.693
# epoch :  52  -  cost:  19812.93
# epoch :  53  -  cost:  18746.771
# epoch :  54  -  cost:  18542.043
# epoch :  55  -  cost:  17896.486
# epoch :  56  -  cost:  17306.201
# epoch :  57  -  cost:  17553.846
# epoch :  58  -  cost:  16885.3
# epoch :  59  -  cost:  15731.352
# epoch :  60  -  cost:  15641.089
# epoch :  61  -  cost:  15531.698
# epoch :  62  -  cost:  14882.5205
# epoch :  63  -  cost:  14512.128
# epoch :  64  -  cost:  14063.756
# epoch :  65  -  cost:  13546.729
# epoch :  66  -  cost:  13597.06
# epoch :  67  -  cost:  12941.766
# epoch :  68  -  cost:  12474.264
# epoch :  69  -  cost:  12396.567
# epoch :  70  -  cost:  11979.608
# epoch :  71  -  cost:  11661.495
# epoch :  72  -  cost:  11250.437
# epoch :  73  -  cost:  11038.681
# epoch :  74  -  cost:  10803.171
# epoch :  75  -  cost:  10294.914
# epoch :  76  -  cost:  10134.404
# epoch :  77  -  cost:  9869.704
# epoch :  78  -  cost:  9579.263
# epoch :  79  -  cost:  9230.932
# epoch :  80  -  cost:  9104.108
# epoch :  81  -  cost:  8766.492
# epoch :  82  -  cost:  8499.293
# epoch :  83  -  cost:  8294.4375
# epoch :  84  -  cost:  8078.045
# epoch :  85  -  cost:  7768.1953
# epoch :  86  -  cost:  7600.984
# epoch :  87  -  cost:  7366.939
# epoch :  88  -  cost:  7130.108
# epoch :  89  -  cost:  6941.503
# epoch :  90  -  cost:  6726.7876
# epoch :  91  -  cost:  6514.6016
# epoch :  92  -  cost:  6318.2837
# epoch :  93  -  cost:  6141.376
# epoch :  94  -  cost:  5952.8877
# epoch :  95  -  cost:  5770.9946
# epoch :  96  -  cost:  5589.2197
# epoch :  97  -  cost:  5421.221
# epoch :  98  -  cost:  5263.7573
# epoch :  99  -  cost:  5097.2734
# epoch :  100  -  cost:  4948.7783
# epoch :  101  -  cost:  4789.2075
# epoch :  102  -  cost:  4623.972
# epoch :  103  -  cost:  4482.637
# epoch :  104  -  cost:  4337.145
# epoch :  105  -  cost:  4211.2646
# epoch :  106  -  cost:  4073.4983
# epoch :  107  -  cost:  3986.439
# epoch :  108  -  cost:  3864.3115
# epoch :  109  -  cost:  3763.0195
# epoch :  110  -  cost:  3562.7888
# epoch :  111  -  cost:  3404.0112
# epoch :  112  -  cost:  3351.028
# epoch :  113  -  cost:  3280.109
# epoch :  114  -  cost:  3177.236
# epoch :  115  -  cost:  2980.6548
# epoch :  116  -  cost:  2890.3398
# epoch :  117  -  cost:  2854.1772
# epoch :  118  -  cost:  2706.8958
# epoch :  119  -  cost:  2584.338
# epoch :  120  -  cost:  2519.5044
# epoch :  121  -  cost:  2444.0295
# epoch :  122  -  cost:  2322.9192
# epoch :  123  -  cost:  2243.2666
# epoch :  124  -  cost:  2164.0745
# epoch :  125  -  cost:  2109.698
# epoch :  126  -  cost:  2011.486
# epoch :  127  -  cost:  1925.9537
# epoch :  128  -  cost:  1851.2709
# epoch :  129  -  cost:  1773.5634
# epoch :  130  -  cost:  1704.9313
# epoch :  131  -  cost:  1638.0968
# epoch :  132  -  cost:  1597.8636
# epoch :  133  -  cost:  1654.847
# epoch :  134  -  cost:  1823.6965
# epoch :  135  -  cost:  2165.6206
# epoch :  136  -  cost:  1588.2128
# epoch :  137  -  cost:  1355.6681
# epoch :  138  -  cost:  1469.8652
# epoch :  139  -  cost:  1308.9696
# epoch :  140  -  cost:  1234.2567
# epoch :  141  -  cost:  1203.9092
# epoch :  142  -  cost:  1127.6857
# epoch :  143  -  cost:  1155.26
# epoch :  144  -  cost:  1020.548
# epoch :  145  -  cost:  1113.5063
# epoch :  146  -  cost:  960.3094
# epoch :  147  -  cost:  966.21954
# epoch :  148  -  cost:  931.13684
# epoch :  149  -  cost:  832.9195
# epoch :  150  -  cost:  803.90247
# epoch :  151  -  cost:  785.53375
# epoch :  152  -  cost:  722.8862
# epoch :  153  -  cost:  697.62317
# epoch :  154  -  cost:  679.25977
# epoch :  155  -  cost:  638.7217
# epoch :  156  -  cost:  593.0826
# epoch :  157  -  cost:  590.45514
# epoch :  158  -  cost:  546.40625
# epoch :  159  -  cost:  506.68732
# epoch :  160  -  cost:  488.44162
# epoch :  161  -  cost:  463.57056
# epoch :  162  -  cost:  430.97485
# epoch :  163  -  cost:  417.15878
# epoch :  164  -  cost:  393.93036
# epoch :  165  -  cost:  366.10406
# epoch :  166  -  cost:  343.4562
# epoch :  167  -  cost:  335.03232
# epoch :  168  -  cost:  348.0221
# epoch :  169  -  cost:  462.39786
# epoch :  170  -  cost:  627.46094
# epoch :  171  -  cost:  705.5347
# epoch :  172  -  cost:  434.5312
# epoch :  173  -  cost:  270.27728
# epoch :  174  -  cost:  388.42694
# epoch :  175  -  cost:  334.633
# epoch :  176  -  cost:  279.5272
# epoch :  177  -  cost:  243.08336
# epoch :  178  -  cost:  358.80786
# epoch :  179  -  cost:  227.9565
# epoch :  180  -  cost:  705.08813
# epoch :  181  -  cost:  1455.3956
# epoch :  182  -  cost:  204.63162
# epoch :  183  -  cost:  1906.3972
# epoch :  184  -  cost:  2423.6255
# epoch :  185  -  cost:  254.7201
# epoch :  186  -  cost:  1198.7017
# epoch :  187  -  cost:  280.52765
# epoch :  188  -  cost:  1342.9294
# epoch :  189  -  cost:  626.43274
# epoch :  190  -  cost:  973.09393
# epoch :  191  -  cost:  849.25195
# epoch :  192  -  cost:  652.4311
# epoch :  193  -  cost:  304.363
# epoch :  194  -  cost:  1385.0851
# epoch :  195  -  cost:  991.06775
# epoch :  196  -  cost:  860.4208
# epoch :  197  -  cost:  383.5411
# epoch :  198  -  cost:  2022.6842
# epoch :  199  -  cost:  1324.9082
# epoch :  200  -  cost:  700.40106
# epoch :  201  -  cost:  316.90912
# epoch :  202  -  cost:  2517.1294
# epoch :  203  -  cost:  394.0079
# epoch :  204  -  cost:  5536.013
# epoch :  205  -  cost:  121.627365
# epoch :  206  -  cost:  5649.333
# epoch :  207  -  cost:  160.2983
# epoch :  208  -  cost:  2360.539
# epoch :  209  -  cost:  162.63133
# epoch :  210  -  cost:  340.54364
# epoch :  211  -  cost:  1261.732
# epoch :  212  -  cost:  118.70641
# epoch :  213  -  cost:  1188.2288
# epoch :  214  -  cost:  212.30281
# epoch :  215  -  cost:  130.8253
# epoch :  216  -  cost:  621.6107
# epoch :  217  -  cost:  116.03286
# epoch :  218  -  cost:  162.14308
# epoch :  219  -  cost:  339.53772
# epoch :  220  -  cost:  237.838
# epoch :  221  -  cost:  108.62362
# epoch :  222  -  cost:  74.19267
# epoch :  223  -  cost:  240.85573
# epoch :  224  -  cost:  95.00862
# epoch :  225  -  cost:  56.446312
# epoch :  226  -  cost:  52.898598
# epoch :  227  -  cost:  72.49054
# epoch :  228  -  cost:  104.7067
# epoch :  229  -  cost:  53.707676
# epoch :  230  -  cost:  33.608376
# epoch :  231  -  cost:  25.989853
# epoch :  232  -  cost:  20.478758
# epoch :  233  -  cost:  18.77452
# epoch :  234  -  cost:  25.808805
# epoch :  235  -  cost:  38.524105
# epoch :  236  -  cost:  21.301344
# epoch :  237  -  cost:  11.100904
# epoch :  238  -  cost:  6.453972
# epoch :  239  -  cost:  3.1173081
# epoch :  240  -  cost:  1.756875
# epoch :  241  -  cost:  0.94162005
# epoch :  242  -  cost:  0.6783306
# epoch :  243  -  cost:  0.45108554
# epoch :  244  -  cost:  0.051118422
# epoch :  245  -  cost:  0.0
# epoch :  246  -  cost:  0.09523027
# epoch :  247  -  cost:  0.4880044
# epoch :  248  -  cost:  0.6113487
# epoch :  249  -  cost:  0.59576756
# epoch :  250  -  cost:  0.3591228
# epoch :  251  -  cost:  0.0
# epoch :  252  -  cost:  0.0
# epoch :  253  -  cost:  0.0017703583
# epoch :  254  -  cost:  0.0
# epoch :  255  -  cost:  0.0
# epoch :  256  -  cost:  0.0
# epoch :  257  -  cost:  0.0
# epoch :  258  -  cost:  0.0
# epoch :  259  -  cost:  0.0
# epoch :  260  -  cost:  0.0
# epoch :  261  -  cost:  0.0
# epoch :  262  -  cost:  0.0
# epoch :  263  -  cost:  0.0
# epoch :  264  -  cost:  0.0
# epoch :  265  -  cost:  0.0
# epoch :  266  -  cost:  0.0
# epoch :  267  -  cost:  0.0
# epoch :  268  -  cost:  0.0
# epoch :  269  -  cost:  0.0
# epoch :  270  -  cost:  0.0
# epoch :  271  -  cost:  0.0
# epoch :  272  -  cost:  0.0
# epoch :  273  -  cost:  0.0
# epoch :  274  -  cost:  0.0
# epoch :  275  -  cost:  0.0
# epoch :  276  -  cost:  0.0
# epoch :  277  -  cost:  0.0
# epoch :  278  -  cost:  0.0
# epoch :  279  -  cost:  0.0
# epoch :  280  -  cost:  0.0
# epoch :  281  -  cost:  0.0
# epoch :  282  -  cost:  0.0
# epoch :  283  -  cost:  0.0
# epoch :  284  -  cost:  0.0
# epoch :  285  -  cost:  0.0
# epoch :  286  -  cost:  0.0
# epoch :  287  -  cost:  0.0
# epoch :  288  -  cost:  0.0
# epoch :  289  -  cost:  0.0
# epoch :  290  -  cost:  0.0
# epoch :  291  -  cost:  0.0
# epoch :  292  -  cost:  0.0
# epoch :  293  -  cost:  0.0
# epoch :  294  -  cost:  0.0
# epoch :  295  -  cost:  0.0
# epoch :  296  -  cost:  0.0
# epoch :  297  -  cost:  0.0
# epoch :  298  -  cost:  0.0
# epoch :  299  -  cost:  0.0
# epoch :  300  -  cost:  0.0
# epoch :  301  -  cost:  0.0
# epoch :  302  -  cost:  0.0
# epoch :  303  -  cost:  0.0
# epoch :  304  -  cost:  0.0
# epoch :  305  -  cost:  0.0
# epoch :  306  -  cost:  0.0
# epoch :  307  -  cost:  0.0
# epoch :  308  -  cost:  0.0
# epoch :  309  -  cost:  0.0
# epoch :  310  -  cost:  0.0
# epoch :  311  -  cost:  0.0
# epoch :  312  -  cost:  0.0
# epoch :  313  -  cost:  0.0
# epoch :  314  -  cost:  0.0
# epoch :  315  -  cost:  0.0
# epoch :  316  -  cost:  0.0
# epoch :  317  -  cost:  0.0
# epoch :  318  -  cost:  0.0
# epoch :  319  -  cost:  0.0
# epoch :  320  -  cost:  0.0
# epoch :  321  -  cost:  0.0
# epoch :  322  -  cost:  0.0
# epoch :  323  -  cost:  0.0
# epoch :  324  -  cost:  0.0
# epoch :  325  -  cost:  0.0
# epoch :  326  -  cost:  0.0
# epoch :  327  -  cost:  0.0
# epoch :  328  -  cost:  0.0
# epoch :  329  -  cost:  0.0
# epoch :  330  -  cost:  0.0
# epoch :  331  -  cost:  0.0
# epoch :  332  -  cost:  0.0
# epoch :  333  -  cost:  0.0
# epoch :  334  -  cost:  0.0
# epoch :  335  -  cost:  0.0
# epoch :  336  -  cost:  0.0
# epoch :  337  -  cost:  0.0
# epoch :  338  -  cost:  0.0
# epoch :  339  -  cost:  0.0
# epoch :  340  -  cost:  0.0
# epoch :  341  -  cost:  0.0
# epoch :  342  -  cost:  0.0
# epoch :  343  -  cost:  0.0
# epoch :  344  -  cost:  0.0
# epoch :  345  -  cost:  0.0
# epoch :  346  -  cost:  0.0
# epoch :  347  -  cost:  0.0
# epoch :  348  -  cost:  0.0
# epoch :  349  -  cost:  0.0
# epoch :  350  -  cost:  0.0
# epoch :  351  -  cost:  0.0
# epoch :  352  -  cost:  0.0
# epoch :  353  -  cost:  0.0
# epoch :  354  -  cost:  0.0
# epoch :  355  -  cost:  0.0
# epoch :  356  -  cost:  0.0
# epoch :  357  -  cost:  0.0
# epoch :  358  -  cost:  0.0
# epoch :  359  -  cost:  0.0
# epoch :  360  -  cost:  0.0
# epoch :  361  -  cost:  0.0
# epoch :  362  -  cost:  0.0
# epoch :  363  -  cost:  0.0
# epoch :  364  -  cost:  0.0
# epoch :  365  -  cost:  0.0
# epoch :  366  -  cost:  0.0
# epoch :  367  -  cost:  0.0
# epoch :  368  -  cost:  0.0
# epoch :  369  -  cost:  0.0
# epoch :  370  -  cost:  0.0
# epoch :  371  -  cost:  0.0
# epoch :  372  -  cost:  0.0
# epoch :  373  -  cost:  0.0
# epoch :  374  -  cost:  0.0
# epoch :  375  -  cost:  0.0
# epoch :  376  -  cost:  0.0
# epoch :  377  -  cost:  0.0
# epoch :  378  -  cost:  0.0
# epoch :  379  -  cost:  0.0
# epoch :  380  -  cost:  0.0
# epoch :  381  -  cost:  0.0
# epoch :  382  -  cost:  0.0
# epoch :  383  -  cost:  0.0
# epoch :  384  -  cost:  0.0
# epoch :  385  -  cost:  0.0
# epoch :  386  -  cost:  0.0
# epoch :  387  -  cost:  0.0
# epoch :  388  -  cost:  0.0
# epoch :  389  -  cost:  0.0
# epoch :  390  -  cost:  0.0
# epoch :  391  -  cost:  0.0
# epoch :  392  -  cost:  0.0
# epoch :  393  -  cost:  0.0
# epoch :  394  -  cost:  0.0
# epoch :  395  -  cost:  0.0
# epoch :  396  -  cost:  0.0
# epoch :  397  -  cost:  0.0
# epoch :  398  -  cost:  0.0
# epoch :  399  -  cost:  0.0
# epoch :  400  -  cost:  0.0
# epoch :  401  -  cost:  0.0
# epoch :  402  -  cost:  0.0
# epoch :  403  -  cost:  0.0
# epoch :  404  -  cost:  0.0
# epoch :  405  -  cost:  0.0
# epoch :  406  -  cost:  0.0
# epoch :  407  -  cost:  0.0
# epoch :  408  -  cost:  0.0
# epoch :  409  -  cost:  0.0
# epoch :  410  -  cost:  0.0
# epoch :  411  -  cost:  0.0
# epoch :  412  -  cost:  0.0
# epoch :  413  -  cost:  0.0
# epoch :  414  -  cost:  0.0
# epoch :  415  -  cost:  0.0
# epoch :  416  -  cost:  0.0
# epoch :  417  -  cost:  0.0
# epoch :  418  -  cost:  0.0
# epoch :  419  -  cost:  0.0
# epoch :  420  -  cost:  0.0
# epoch :  421  -  cost:  0.0
# epoch :  422  -  cost:  0.0
# epoch :  423  -  cost:  0.0
# epoch :  424  -  cost:  0.0
# epoch :  425  -  cost:  0.0
# epoch :  426  -  cost:  0.0
# epoch :  427  -  cost:  0.0
# epoch :  428  -  cost:  0.0
# epoch :  429  -  cost:  0.0
# epoch :  430  -  cost:  0.0
# epoch :  431  -  cost:  0.0
# epoch :  432  -  cost:  0.0
# epoch :  433  -  cost:  0.0
# epoch :  434  -  cost:  0.0
# epoch :  435  -  cost:  0.0
# epoch :  436  -  cost:  0.0
# epoch :  437  -  cost:  0.0
# epoch :  438  -  cost:  0.0
# epoch :  439  -  cost:  0.0
# epoch :  440  -  cost:  0.0
# epoch :  441  -  cost:  0.0
# epoch :  442  -  cost:  0.0
# epoch :  443  -  cost:  0.0
# epoch :  444  -  cost:  0.0
# epoch :  445  -  cost:  0.0
# epoch :  446  -  cost:  0.0
# epoch :  447  -  cost:  0.0
# epoch :  448  -  cost:  0.0
# epoch :  449  -  cost:  0.0
# epoch :  450  -  cost:  0.0
# epoch :  451  -  cost:  0.0
# epoch :  452  -  cost:  0.0
# epoch :  453  -  cost:  0.0
# epoch :  454  -  cost:  0.0
# epoch :  455  -  cost:  0.0
# epoch :  456  -  cost:  0.0
# epoch :  457  -  cost:  0.0
# epoch :  458  -  cost:  0.0
# epoch :  459  -  cost:  0.0
# epoch :  460  -  cost:  0.0
# epoch :  461  -  cost:  0.0
# epoch :  462  -  cost:  0.0
# epoch :  463  -  cost:  0.0
# epoch :  464  -  cost:  0.0
# epoch :  465  -  cost:  0.0
# epoch :  466  -  cost:  0.0
# epoch :  467  -  cost:  0.0
# epoch :  468  -  cost:  0.0
# epoch :  469  -  cost:  0.0
# epoch :  470  -  cost:  0.0
# epoch :  471  -  cost:  0.0
# epoch :  472  -  cost:  0.0
# epoch :  473  -  cost:  0.0
# epoch :  474  -  cost:  0.0
# epoch :  475  -  cost:  0.0
# epoch :  476  -  cost:  0.0
# epoch :  477  -  cost:  0.0
# epoch :  478  -  cost:  0.0
# epoch :  479  -  cost:  0.0
# epoch :  480  -  cost:  0.0
# epoch :  481  -  cost:  0.0
# epoch :  482  -  cost:  0.0
# epoch :  483  -  cost:  0.0
# epoch :  484  -  cost:  0.0
# epoch :  485  -  cost:  0.0
# epoch :  486  -  cost:  0.0
# epoch :  487  -  cost:  0.0
# epoch :  488  -  cost:  0.0
# epoch :  489  -  cost:  0.0
# epoch :  490  -  cost:  0.0
# epoch :  491  -  cost:  0.0
# epoch :  492  -  cost:  0.0
# epoch :  493  -  cost:  0.0
# epoch :  494  -  cost:  0.0
# epoch :  495  -  cost:  0.0
# epoch :  496  -  cost:  0.0
# epoch :  497  -  cost:  0.0
# epoch :  498  -  cost:  0.0
# epoch :  499  -  cost:  0.0

# %%
import matplotlib.pyplot as plt
plt.figure()
plt.plot(range(0,500), cost_history[0:500])
plt.ylabel('COST')
plt.xlabel('EPOCH')
plt.ylim([0, 1000])
plt.show()

# %%
test_y=test_y.todense() 
correct_prediction = tf.equal(tf.argmax(model,1), tf.argmax(y_,1))   
accuracy = tf.reduce_mean(tf.cast(correct_prediction, tf.float32))
print("Accuracy: ", sess.run(accuracy, feed_dict={x: test_x, y_:test_y}))
# Out:
# Accuracy:  0.6533333
